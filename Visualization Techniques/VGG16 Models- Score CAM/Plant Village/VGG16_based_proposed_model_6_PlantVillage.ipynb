# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

a = tf.constant(0.)
b = 2 * a
g = tf.gradients(a + b, [a, b])
hello = tf.constant('Hello, TensorFlow!')

sess = tf.compat.v1.Session()
with tf.compat.v1.Session() as sess:
    print(sess.run(g))
# Out:
# [3.0, 1.0]

# %%
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Flatten, Dense, Conv2D, ZeroPadding2D, Convolution2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
class MyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        # print('Accuracy:', logs.get('accuracy', 0))
        if logs.get('accuracy') >= 0.95:
            # print('inside if')
            self.model.stop_training = True

callback = MyCallback()

# %%
# Load the dataset
data_path = '/content/drive/MyDrive/PlantVillage/Train'

train_datagen = ImageDataGenerator(rescale=1./255)
train_datagenerator = train_datagen.flow_from_directory(
    data_path,
    target_size=(224, 224),
    class_mode='categorical',
    batch_size= 32
)

validation_data_path = '/content/drive/MyDrive/PlantVillage/Validation'

validation_datagen = ImageDataGenerator(rescale=1./255)
validation_datagenerator = validation_datagen.flow_from_directory(
    validation_data_path,
    target_size=(224, 224),
    class_mode='categorical',
    batch_size= 32
)
# Out:
# Found 12019 images belonging to 10 classes.
# Found 3858 images belonging to 10 classes.

# %%
from keras.models import Sequential
from keras.optimizers import Adam
from tensorflow.keras import models

def build_Sequential():
  model = Sequential()
  model.add(ZeroPadding2D((1,1),input_shape=(224,224,3)))
  model.add(Convolution2D(64, 3, 3, activation='relu', name= "block1_conv1" ))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(64, 3, 3, activation='relu', name = "block1_conv2"))
  model.add(MaxPooling2D((2,2), strides=(2,2)))

  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(128, 3, 3, activation='relu', name= "block2_conv1"))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(128, 3, 3, activation='relu', name = "block2_conv2" ))
  model.add(MaxPooling2D((2,2), strides=(2,2), padding='same'))

  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(256, 3, 3, activation='relu', name = "block3_conv1" ))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(256, 3, 3, activation='relu', name = 'block3_conv2'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(256, 3, 3, activation='relu', name = 'block3_conv3'))
  model.add(MaxPooling2D((2,2), strides=(2,2), padding='same'))

  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu', name = 'block4_conv1'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu', name = 'block4_conv2'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu', name = 'block4_conv3'))
  model.add(MaxPooling2D((2,2), strides=(2,2), padding='same'))

  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu', name = 'block5_conv1'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu', name = 'block5_conv2'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu', name = 'block5_conv3'))
  model.add(MaxPooling2D((2,2), strides=(2,2), padding='same'))

  # model.add(Flatten())
  # model.add(Dense(4096, activation='relu'))
  # model.add(Dropout(0.5))
  # model.add(Dense(4096, activation='relu'))
  # model.add(Dropout(0.5))
  # model.add(Dense(10, activation='softmax'))

  Flat_layer = Flatten()(model.layers[-1].output)
  Dense_1 = Dense(4096, activation='relu')(Flat_layer)
  Output = Dense(10, activation='softmax')(Dense_1) 
  model = Model(inputs=model.inputs, outputs=Output)
  model.call = tf.function(model.call)

#sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='categorical_crossentropy')

  model.compile(optimizer=Adam(0.0001),loss='categorical_crossentropy',metrics=['accuracy'])
  return model

# %%
model = build_Sequential()

# %%
history = model.fit(train_datagenerator,epochs=500,validation_data=validation_datagenerator,steps_per_epoch=16, callbacks=[callback])
# Out:
# Epoch 1/500
# 16/16 [==============================] - 17s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4175 - accuracy: 0.8555 - val_loss: 0.6585 - val_accuracy: 0.8082
# Epoch 2/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4784 - accuracy: 0.8203 - val_loss: 0.4814 - val_accuracy: 0.8320
# Epoch 3/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4315 - accuracy: 0.8125 - val_loss: 0.4962 - val_accuracy: 0.8463
# Epoch 4/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3649 - accuracy: 0.8574 - val_loss: 0.4866 - val_accuracy: 0.8442
# Epoch 5/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3492 - accuracy: 0.8633 - val_loss: 0.5098 - val_accuracy: 0.8341
# Epoch 6/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4192 - accuracy: 0.8359 - val_loss: 0.6501 - val_accuracy: 0.8165
# Epoch 7/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3988 - accuracy: 0.8398 - val_loss: 0.6099 - val_accuracy: 0.8100
# Epoch 8/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4147 - accuracy: 0.8438 - val_loss: 0.5586 - val_accuracy: 0.7981
# Epoch 9/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4370 - accuracy: 0.8047 - val_loss: 0.5467 - val_accuracy: 0.8248
# Epoch 10/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4175 - accuracy: 0.8379 - val_loss: 0.5680 - val_accuracy: 0.8167
# Epoch 11/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3081 - accuracy: 0.8906 - val_loss: 0.4813 - val_accuracy: 0.8497
# Epoch 12/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3983 - accuracy: 0.8516 - val_loss: 0.5356 - val_accuracy: 0.8339
# Epoch 13/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3709 - accuracy: 0.8750 - val_loss: 0.5188 - val_accuracy: 0.8432
# Epoch 14/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3669 - accuracy: 0.8633 - val_loss: 0.5927 - val_accuracy: 0.8289
# Epoch 15/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3265 - accuracy: 0.8516 - val_loss: 0.5083 - val_accuracy: 0.8491
# Epoch 16/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 31.1875 - loss: 0.3657 - accuracy: 0.8557 - val_loss: 0.5170 - val_accuracy: 0.8429
# Epoch 17/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3362 - accuracy: 0.8789 - val_loss: 0.5382 - val_accuracy: 0.8396
# Epoch 18/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3341 - accuracy: 0.8613 - val_loss: 0.5151 - val_accuracy: 0.8440
# Epoch 19/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3837 - accuracy: 0.8359 - val_loss: 0.5228 - val_accuracy: 0.8463
# Epoch 20/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4531 - accuracy: 0.8613 - val_loss: 0.6728 - val_accuracy: 0.8072
# Epoch 21/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.5287 - accuracy: 0.7832 - val_loss: 0.6982 - val_accuracy: 0.8097
# Epoch 22/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.5477 - accuracy: 0.8125 - val_loss: 0.4927 - val_accuracy: 0.8370
# Epoch 23/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.5296 - accuracy: 0.8105 - val_loss: 0.6323 - val_accuracy: 0.7950
# Epoch 24/500
# 16/16 [==============================] - 17s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.5237 - accuracy: 0.7930 - val_loss: 0.5785 - val_accuracy: 0.7867
# Epoch 25/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4844 - accuracy: 0.8027 - val_loss: 0.5473 - val_accuracy: 0.8191
# Epoch 26/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4641 - accuracy: 0.8398 - val_loss: 0.8560 - val_accuracy: 0.7556
# Epoch 27/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.5878 - accuracy: 0.8008 - val_loss: 0.4997 - val_accuracy: 0.8294
# Epoch 28/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3392 - accuracy: 0.8477 - val_loss: 0.5354 - val_accuracy: 0.8227
# Epoch 29/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4734 - accuracy: 0.8203 - val_loss: 0.5493 - val_accuracy: 0.8222
# Epoch 30/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4160 - accuracy: 0.8477 - val_loss: 0.4976 - val_accuracy: 0.8437
# Epoch 31/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3552 - accuracy: 0.8633 - val_loss: 0.5157 - val_accuracy: 0.8403
# Epoch 32/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3582 - accuracy: 0.8477 - val_loss: 0.5857 - val_accuracy: 0.8095
# Epoch 33/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3149 - accuracy: 0.8633 - val_loss: 0.4944 - val_accuracy: 0.8473
# Epoch 34/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3957 - accuracy: 0.8398 - val_loss: 0.7060 - val_accuracy: 0.7805
# Epoch 35/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.5549 - accuracy: 0.7852 - val_loss: 0.6734 - val_accuracy: 0.8108
# Epoch 36/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.5738 - accuracy: 0.7910 - val_loss: 0.5386 - val_accuracy: 0.8217
# Epoch 37/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4506 - accuracy: 0.8438 - val_loss: 0.5571 - val_accuracy: 0.8206
# Epoch 38/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3893 - accuracy: 0.8242 - val_loss: 0.5065 - val_accuracy: 0.8385
# Epoch 39/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3633 - accuracy: 0.8672 - val_loss: 0.5400 - val_accuracy: 0.8227
# Epoch 40/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3730 - accuracy: 0.8594 - val_loss: 0.5048 - val_accuracy: 0.8398
# Epoch 41/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3964 - accuracy: 0.8438 - val_loss: 0.5624 - val_accuracy: 0.8263
# Epoch 42/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3614 - accuracy: 0.8809 - val_loss: 0.5143 - val_accuracy: 0.8351
# Epoch 43/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3373 - accuracy: 0.8828 - val_loss: 0.4771 - val_accuracy: 0.8484
# Epoch 44/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 31.1875 - loss: 0.4926 - accuracy: 0.8236 - val_loss: 0.5757 - val_accuracy: 0.8188
# Epoch 45/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4387 - accuracy: 0.8242 - val_loss: 0.4877 - val_accuracy: 0.8463
# Epoch 46/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4830 - accuracy: 0.8105 - val_loss: 0.6302 - val_accuracy: 0.8142
# Epoch 47/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4969 - accuracy: 0.8281 - val_loss: 0.5624 - val_accuracy: 0.8183
# Epoch 48/500
# 16/16 [==============================] - 17s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3750 - accuracy: 0.8516 - val_loss: 0.5141 - val_accuracy: 0.8294
# Epoch 49/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4289 - accuracy: 0.8320 - val_loss: 0.5325 - val_accuracy: 0.8393
# Epoch 50/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3912 - accuracy: 0.8477 - val_loss: 0.4911 - val_accuracy: 0.8455
# Epoch 51/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3769 - accuracy: 0.8652 - val_loss: 0.4840 - val_accuracy: 0.8554
# Epoch 52/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3854 - accuracy: 0.8516 - val_loss: 0.6300 - val_accuracy: 0.8245
# Epoch 53/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 31.1875 - loss: 0.3506 - accuracy: 0.8697 - val_loss: 0.4826 - val_accuracy: 0.8497
# Epoch 54/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.8430 - accuracy: 0.7656 - val_loss: 1.0440 - val_accuracy: 0.7055
# Epoch 55/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.5857 - accuracy: 0.7695 - val_loss: 0.5559 - val_accuracy: 0.8248
# Epoch 56/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4248 - accuracy: 0.8496 - val_loss: 0.5544 - val_accuracy: 0.8212
# Epoch 57/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4683 - accuracy: 0.8164 - val_loss: 0.6122 - val_accuracy: 0.8154
# Epoch 58/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4400 - accuracy: 0.8418 - val_loss: 0.5794 - val_accuracy: 0.8180
# Epoch 59/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3668 - accuracy: 0.8730 - val_loss: 0.5221 - val_accuracy: 0.8390
# Epoch 60/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4595 - accuracy: 0.8496 - val_loss: 0.5538 - val_accuracy: 0.8188
# Epoch 61/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3972 - accuracy: 0.8652 - val_loss: 0.4860 - val_accuracy: 0.8390
# Epoch 62/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3634 - accuracy: 0.8574 - val_loss: 0.4608 - val_accuracy: 0.8497
# Epoch 63/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2970 - accuracy: 0.8711 - val_loss: 0.4541 - val_accuracy: 0.8559
# Epoch 64/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4714 - accuracy: 0.8320 - val_loss: 0.5848 - val_accuracy: 0.8147
# Epoch 65/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.4193 - accuracy: 0.8555 - val_loss: 0.4767 - val_accuracy: 0.8486
# Epoch 66/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.
500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2184 - accuracy: 0.9316 - val_loss: 0.4570 - val_accuracy: 0.8642
# Epoch 219/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2835 - accuracy: 0.9121 - val_loss: 0.5262 - val_accuracy: 0.8525
# Epoch 220/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2758 - accuracy: 0.9277 - val_loss: 0.4331 - val_accuracy: 0.8694
# Epoch 221/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2242 - accuracy: 0.9277 - val_loss: 0.4137 - val_accuracy: 0.8795
# Epoch 222/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2835 - accuracy: 0.8984 - val_loss: 0.4816 - val_accuracy: 0.8634
# Epoch 223/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 31.1875 - loss: 0.3366 - accuracy: 0.8958 - val_loss: 0.4609 - val_accuracy: 0.8618
# Epoch 224/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2929 - accuracy: 0.8809 - val_loss: 0.4133 - val_accuracy: 0.8815
# Epoch 225/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2898 - accuracy: 0.8926 - val_loss: 0.5475 - val_accuracy: 0.8491
# Epoch 226/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.3176 - accuracy: 0.8906 - val_loss: 0.4655 - val_accuracy: 0.8520
# Epoch 227/500
# 16/16 [==============================] - 15s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2189 - accuracy: 0.9336 - val_loss: 0.4888 - val_accuracy: 0.8580
# Epoch 228/500
# 16/16 [==============================] - 15s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2064 - accuracy: 0.9258 - val_loss: 0.4405 - val_accuracy: 0.8795
# Epoch 229/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.1964 - accuracy: 0.9473 - val_loss: 0.4520 - val_accuracy: 0.8675
# Epoch 230/500
# 16/16 [==============================] - 15s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2150 - accuracy: 0.9258 - val_loss: 0.4627 - val_accuracy: 0.8727
# Epoch 231/500
# 16/16 [==============================] - 15s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2489 - accuracy: 0.9141 - val_loss: 0.4487 - val_accuracy: 0.8735
# Epoch 232/500
# 16/16 [==============================] - 15s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2296 - accuracy: 0.9258 - val_loss: 0.4587 - val_accuracy: 0.8782
# Epoch 233/500
# 16/16 [==============================] - 15s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2500 - accuracy: 0.9004 - val_loss: 0.4401 - val_accuracy: 0.8805
# Epoch 234/500
# 16/16 [==============================] - 15s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2346 - accuracy: 0.9180 - val_loss: 0.5542 - val_accuracy: 0.8644
# Epoch 235/500
# 16/16 [==============================] - 16s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2025 - accuracy: 0.9297 - val_loss: 0.4430 - val_accuracy: 0.8764
# Epoch 236/500
# 16/16 [==============================] - 15s 1s/step - batch: 7.5000 - size: 31.1875 - loss: 0.2146 - accuracy: 0.9238 - val_loss: 0.5165 - val_accuracy: 0.8663
# Epoch 237/500
# 16/16 [==============================] - 15s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2132 - accuracy: 0.9297 - val_loss: 0.4971 - val_accuracy: 0.8639
# Epoch 238/500
# 16/16 [==============================] - 15s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.2352 - accuracy: 0.9414 - val_loss: 0.4365 - val_accuracy: 0.8753
# Epoch 239/500
# 16/16 [==============================] - 15s 1s/step - batch: 7.5000 - size: 32.0000 - loss: 0.1936 - accuracy: 0.9648 - val_loss: 0.4285 - val_accuracy: 0.8904

# %%
#500 epochs + 239

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_input (InputL [(None, 224, 224, 3)]     0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 226, 226, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 75, 75, 64)        1792
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 77, 77, 64)        0
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 14, 14, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 4, 4, 128)         73856
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 6, 6, 128)         0
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 2, 2, 128)         147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 3, 3, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 1, 1, 256)         295168
# _________________________________________________________________
# zero_padding2d_5 (ZeroPaddin (None, 3, 3, 256)         0
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 1, 1, 256)         590080
# _________________________________________________________________
# zero_padding2d_6 (ZeroPaddin (None, 3, 3, 256)         0
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 1, 1, 256)         590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# zero_padding2d_7 (ZeroPaddin (None, 3, 3, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 1, 1, 512)         1180160
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 3, 3, 512)         0
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 1, 1, 512)         2359808
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 3, 3, 512)         0
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 1, 1, 512)         2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# zero_padding2d_10 (ZeroPaddi (None, 3, 3, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 1, 1, 512)         2359808
# _________________________________________________________________
# zero_padding2d_11 (ZeroPaddi (None, 3, 3, 512)         0
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 1, 1, 512)         2359808
# _________________________________________________________________
# zero_padding2d_12 (ZeroPaddi (None, 3, 3, 512)         0
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 1, 1, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 16,856,906
# Trainable params: 16,856,906
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_data_path = '/content/drive/MyDrive/PlantVillage/Test'

test_datagen = ImageDataGenerator(rescale=1./255)
test_datagenerator = test_datagen.flow_from_directory(
    test_data_path,
    target_size=(224, 224),
    class_mode='categorical',
    batch_size= 32
)
# Out:
# Found 2293 images belonging to 10 classes.

# %%
model.evaluate(test_datagenerator)
# Out:
# [0.46450428675032324, 0.8870475]

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
target_names = []

for key in train_datagenerator.class_indices:

    target_names.append(key)

# %%
print(target_names)
# Out:
# ['Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
Y_pred = model.predict_generator(test_datagenerator)

y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print('y_pred')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_v1.py:1301: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Confusion Matrix
# y_pred

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(test_datagenerator.classes, y_pred))
# Out:
# [[ 47  22  21  15  35  27  25 111   6  24]
#  [ 13   5   6   6  14  11   9  34   2   6]
#  [ 20   8  13  10  20  15  23  57   4  11]
#  [ 13   2  12   1   9  10   7  37   4   5]
#  [ 37   6  15   8  29  18  15  75   3  14]
#  [ 26  10  18  11  22  29  26  53   6  23]
#  [ 30   7  20  13  20  10  16  64   5  13]
#  [106  26  43  31  67  81  58 227  26  54]
#  [  6   1   3   2   5   3   4  13   1   5]
#  [ 23  13  17  10  12   9  18  51   1  15]]

# %%
#Print Classification Report

print('Classification Report')

print(classification_report(test_datagenerator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#                                                precision    recall  f1-score   support
#
#                       Tomato___Bacterial_spot       0.15      0.14      0.14       333
#                         Tomato___Early_blight       0.05      0.05      0.05       106
#                          Tomato___Late_blight       0.08      0.07      0.07       181
#                            Tomato___Leaf_Mold       0.01      0.01      0.01       100
#                   Tomato___Septoria_leaf_spot       0.12      0.13      0.13       220
# Tomato___Spider_mites Two-spotted_spider_mite       0.14      0.13      0.13       224
#                          Tomato___Target_Spot       0.08      0.08      0.08       198
#        Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.31      0.32      0.32       719
#                  Tomato___Tomato_mosaic_virus       0.02      0.02      0.02        43
#                              Tomato___healthy       0.09      0.09      0.09       169
#
#                                      accuracy                           0.17      2293
#                                     macro avg       0.10      0.10      0.10      2293
#                                  weighted avg       0.17      0.17      0.17      2293

# %%
#Get the accuracy score

test_score = model.evaluate_generator(test_datagenerator)

print("[INFO] accuracy: {:.2f}%".format(test_score[1] * 100)) 

print("[INFO] Loss: ",test_score[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_v1.py:1273: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# [INFO] accuracy: 88.70%
# [INFO] Loss:  0.46408788880540264

# %%
import matplotlib.pyplot as plt

val_loss = history.history['val_loss']
loss = history.history['loss']
x = range(len(loss))

plt.plot(x, val_loss, label='val_loss')
plt.plot(x, loss, label='loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
x = range(len(accuracy))

plt.plot(x, accuracy, label='accuracy')
plt.plot(x, val_accuracy, label='val_accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):

    """

    This function prints and plots the confusion matrix.

    Normalization can be applied by setting `normalize=True`.

    """

    plt.figure(figsize=(10,10))



    plt.imshow(cm, interpolation='nearest', cmap=cmap)

    plt.title(title)

    plt.colorbar()



    tick_marks = np.arange(len(classes))

    plt.xticks(tick_marks, classes, rotation=45)

    plt.yticks(tick_marks, classes)



    if normalize:

        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

        cm = np.around(cm, decimals=2)

        cm[np.isnan(cm)] = 0.0

        print("Normalized confusion matrix")

    else:

        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):

        plt.text(j, i, cm[i, j],

                 horizontalalignment="center",

                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()

    plt.ylabel('True label')

    plt.xlabel('Predicted label')

# %%
Y_pred = model.predict_generator(test_datagenerator)

y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')

cm = confusion_matrix(test_datagenerator.classes, y_pred)

plot_confusion_matrix(cm, target_names, title='Confusion Matrix')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training_v1.py:1301: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# Confusion Matrix
# Normalized confusion matrix
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-fb0b4cef261d> in <module>()
#       7 cm = confusion_matrix(test_datagenerator.classes, y_pred)
#       8
# ----> 9 plot_confusion_matrix(cm, target_names, title='Confusion Matrix')
#
# <ipython-input-22-cadfd58dd643> in plot_confusion_matrix(cm, classes, normalize, title, cmap)
#      47     thresh = cm.max() / 2.
#      48
# ---> 49     for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
#      50
#      51         plt.text(j, i, cm[i, j],
#
# NameError: name 'itertools' is not defined

# %%
layer_outputs = [layer.output for layer in model.layers[:-1]]

# %%
layer_outputs
# Out:
# [<tf.Tensor 'zero_padding2d_input:0' shape=(None, 224, 224, 3) dtype=float32>,
#  <tf.Tensor 'zero_padding2d/Pad:0' shape=(None, 226, 226, 3) dtype=float32>,
#  <tf.Tensor 'block1_conv1/Relu:0' shape=(None, 75, 75, 64) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_1/Pad:0' shape=(None, 77, 77, 64) dtype=float32>,
#  <tf.Tensor 'block1_conv2/Relu:0' shape=(None, 25, 25, 64) dtype=float32>,
#  <tf.Tensor 'max_pooling2d/MaxPool:0' shape=(None, 12, 12, 64) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_2/Pad:0' shape=(None, 14, 14, 64) dtype=float32>,
#  <tf.Tensor 'block2_conv1/Relu:0' shape=(None, 4, 4, 128) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_3/Pad:0' shape=(None, 6, 6, 128) dtype=float32>,
#  <tf.Tensor 'block2_conv2/Relu:0' shape=(None, 2, 2, 128) dtype=float32>,
#  <tf.Tensor 'max_pooling2d_1/MaxPool:0' shape=(None, 1, 1, 128) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_4/Pad:0' shape=(None, 3, 3, 128) dtype=float32>,
#  <tf.Tensor 'block3_conv1/Relu:0' shape=(None, 1, 1, 256) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_5/Pad:0' shape=(None, 3, 3, 256) dtype=float32>,
#  <tf.Tensor 'block3_conv2/Relu:0' shape=(None, 1, 1, 256) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_6/Pad:0' shape=(None, 3, 3, 256) dtype=float32>,
#  <tf.Tensor 'block3_conv3/Relu:0' shape=(None, 1, 1, 256) dtype=float32>,
#  <tf.Tensor 'max_pooling2d_2/MaxPool:0' shape=(None, 1, 1, 256) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_7/Pad:0' shape=(None, 3, 3, 256) dtype=float32>,
#  <tf.Tensor 'block4_conv1/Relu:0' shape=(None, 1, 1, 512) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_8/Pad:0' shape=(None, 3, 3, 512) dtype=float32>,
#  <tf.Tensor 'block4_conv2/Relu:0' shape=(None, 1, 1, 512) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_9/Pad:0' shape=(None, 3, 3, 512) dtype=float32>,
#  <tf.Tensor 'block4_conv3/Relu:0' shape=(None, 1, 1, 512) dtype=float32>,
#  <tf.Tensor 'max_pooling2d_3/MaxPool:0' shape=(None, 1, 1, 512) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_10/Pad:0' shape=(None, 3, 3, 512) dtype=float32>,
#  <tf.Tensor 'block5_conv1/Relu:0' shape=(None, 1, 1, 512) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_11/Pad:0' shape=(None, 3, 3, 512) dtype=float32>,
#  <tf.Tensor 'block5_conv2/Relu:0' shape=(None, 1, 1, 512) dtype=float32>,
#  <tf.Tensor 'zero_padding2d_12/Pad:0' shape=(None, 3, 3, 512) dtype=float32>,
#  <tf.Tensor 'block5_conv3/Relu:0' shape=(None, 1, 1, 512) dtype=float32>,
#  <tf.Tensor 'max_pooling2d_4/MaxPool:0' shape=(None, 1, 1, 512) dtype=float32>,
#  <tf.Tensor 'flatten/Reshape:0' shape=(None, 512) dtype=float32>,
#  <tf.Tensor 'dense/Relu:0' shape=(None, 4096) dtype=float32>]

# %%
for layer in model.layers:
    print(layer.output_shape)
# Out:
# [(None, 224, 224, 3)]
# (None, 226, 226, 3)
# (None, 75, 75, 64)
# (None, 77, 77, 64)
# (None, 25, 25, 64)
# (None, 12, 12, 64)
# (None, 14, 14, 64)
# (None, 4, 4, 128)
# (None, 6, 6, 128)
# (None, 2, 2, 128)
# (None, 1, 1, 128)
# (None, 3, 3, 128)
# (None, 1, 1, 256)
# (None, 3, 3, 256)
# (None, 1, 1, 256)
# (None, 3, 3, 256)
# (None, 1, 1, 256)
# (None, 1, 1, 256)
# (None, 3, 3, 256)
# (None, 1, 1, 512)
# (None, 3, 3, 512)
# (None, 1, 1, 512)
# (None, 3, 3, 512)
# (None, 1, 1, 512)
# (None, 1, 1, 512)
# (None, 3, 3, 512)
# (None, 1, 1, 512)
# (None, 3, 3, 512)
# (None, 1, 1, 512)
# (None, 3, 3, 512)
# (None, 1, 1, 512)
# (None, 1, 1, 512)
# (None, 512)
# (None, 4096)
# (None, 10)

# %%
from tensorflow.keras.preprocessing.image import load_img
import matplotlib.pyplot as plt

orig_img = np.array(load_img('/content/drive/MyDrive/PlantVillage/Test/Tomato___Bacterial_spot/dbda016b-fd39-451d-82e5-08e42ea6bcda___GCREC_Bact.Sp 3285.JPG'),dtype=np.uint8)
plt.imshow(orig_img)
plt.show()

# %%
# !cp '/content/drive/MyDrive/Colab Notebooks/scorecamutil.py' .

# %%
tf.keras.models.save_model(
    model,
    './trained_model_vgg_scorecam.h5',
    overwrite=True,
    include_optimizer=True
)

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import cv2
import numpy as np
from scorecamutil import GradCam, GradCamPlusPlus, ScoreCam, build_guided_model, GuidedBackPropagation, superimpose, read_and_preprocess_img

def build_Sequential_and_load():
    model = build_Sequential()
    model.load_weights('/content/trained_model_vgg_scorecam.h5')
    return model

img_path = '/content/drive/MyDrive/PlantVillage/Test/Tomato___Bacterial_spot/dbda016b-fd39-451d-82e5-08e42ea6bcda___GCREC_Bact.Sp 3285.JPG'
orig_img = np.array(load_img(img_path),dtype=np.uint8)
img_array = read_and_preprocess_img(img_path, size=(224,224))

layer_name = 'block1_conv1'

# predictions = model.predict(img_array)
# top = decode_predictions(predictions, top=5)[0]
# print(img_path)
# print("class activation map for:",top[0])

grad_cam=GradCam(model,img_array,layer_name)
grad_cam_superimposed = superimpose(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)

score_cam=ScoreCam(model,img_array,layer_name)
score_cam_superimposed = superimpose(img_path, score_cam)
score_cam_emphasized = superimpose(img_path, score_cam, emphasize=True)

faster_score_cam=ScoreCam(model,img_array,layer_name, max_N=10)
faster_score_cam_superimposed = superimpose(img_path, faster_score_cam)
faster_score_cam_emphasized = superimpose(img_path, faster_score_cam, emphasize=True)

guided_model = build_guided_model(build_Sequential_and_load)
saliency = GuidedBackPropagation(guided_model, img_array, layer_name)
saliency_resized = cv2.resize(saliency, (orig_img.shape[1], orig_img.shape[0]))

grad_cam_resized = cv2.resize(grad_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam = saliency_resized * grad_cam_resized[..., np.newaxis]

grad_cam_plus_plus_resized = cv2.resize(grad_cam_plus_plus, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam_plus_plus = saliency_resized * grad_cam_plus_plus_resized[..., np.newaxis]

score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_score_cam = saliency_resized * score_cam_resized[..., np.newaxis]

faster_score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_faster_score_cam = saliency_resized * faster_score_cam_resized[..., np.newaxis]

img_gray = cv2.imread(img_path, 0)
dx = cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=3)
dy = cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=3)
grad = np.sqrt(dx ** 2 + dy ** 2)  # 画像の勾配を取得
grad = cv2.dilate(grad,kernel=np.ones((5,5)), iterations=1)  # 太らせる処理
grad -= np.min(grad)
grad /= np.max(grad)  # scale 0. to 1.

grad_times_grad_cam = grad * grad_cam_resized
grad_times_grad_cam_plus_plus = grad * grad_cam_plus_plus_resized
grad_times_score_cam = grad * score_cam_resized
grad_times_faster_score_cam = grad * faster_score_cam_resized

fig, ax = plt.subplots(nrows=4,ncols=5, figsize=(18, 11))
ax[0,0].imshow(orig_img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam_superimposed)
ax[0,1].set_title("Grad-CAM")
ax[0,2].imshow(grad_cam_plus_plus_superimposed)
ax[0,2].set_title("Grad-CAM++")
ax[0,3].imshow(score_cam_superimposed)
ax[0,3].set_title("Score-CAM")
ax[0,4].imshow(faster_score_cam_superimposed)
ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(orig_img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_emphasized)
ax[1,1].set_title("Grad-CAM emphasized")
ax[1,2].imshow(grad_cam_plus_plus_emphasized)
ax[1,2].set_title("Grad-CAM++ emphasized")
ax[1,3].imshow(score_cam_emphasized)
ax[1,3].set_title("Score-CAM emphasized")
ax[1,4].imshow(faster_score_cam_emphasized)
ax[1,4].set_title("Faster-Score-CAM emphasized")
ax[2,0].imshow(saliency_resized)
ax[2,0].set_title("Guided-BP")
ax[2,1].imshow(guided_grad_cam)
ax[2,1].set_title("Guided-Grad-CAM")
ax[2,2].imshow(guided_grad_cam_plus_plus)
ax[2,2].set_title("Guided-Grad-CAM++")
ax[2,3].imshow(guided_score_cam)
ax[2,3].set_title("Guided-Score-CAM")
ax[2,4].imshow(guided_faster_score_cam)
ax[2,4].set_title("Guided-Faster-Score-CAM")
ax[3,0].imshow(grad, 'gray')
ax[3,0].set_title("grad")
ax[3,1].imshow(grad_times_grad_cam, 'gray')
ax[3,1].set_title("grad * Grad-CAM")
ax[3,2].imshow(grad_times_grad_cam_plus_plus, 'gray')
ax[3,2].set_title("grad * Grad-CAM++")
ax[3,3].imshow(grad_times_score_cam, 'gray')
ax[3,3].set_title("grad * Score-CAM")
ax[3,4].imshow(grad_times_faster_score_cam, 'gray')
ax[3,4].set_title("grad * Faster-Score-CAM")
for i in range(4):
    for j in range(5):
        ax[i,j].axis('off')
plt.show()
# Out:
# /content/scorecamutil.py:41: RuntimeWarning: invalid value encountered in true_divide
#   cam /= np.max(cam)  # scale 0 to 1.0
# /content/scorecamutil.py:67: RuntimeWarning: invalid value encountered in true_divide
#   alphas /= alpha_normalization_constant.reshape((1,1,conv_first_grad[0].shape[2]))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
print("Grad-CAM")
# %timeit grad_cam = GradCam(model, img_array, layer_name)
print("Grad-CAM++")
# %timeit grad_cam_plus_plus = GradCamPlusPlus(model, img_array, layer_name)
print("Score-Cam")
# %timeit score_cam = ScoreCam(model, img_array, layer_name)
print("Faster-Score-Cam N=10")
# %timeit faster_score_cam = ScoreCam(model, img_array, layer_name, max_N=10)
print("Faster-Score-Cam N=3")
# %timeit faster_score_cam = ScoreCam(model, img_array, layer_name, max_N=3)
print("Guided-BP")
# %timeit saliency = GuidedBackPropagation(guided_model, img_array, layer_name)
# Out:
# Grad-CAM
# /content/scorecamutil.py:41: RuntimeWarning: invalid value encountered in true_divide
#   cam /= np.max(cam)  # scale 0 to 1.0
# 1 loop, best of 5: 392 ms per loop
# Grad-CAM++
# /content/scorecamutil.py:67: RuntimeWarning: invalid value encountered in true_divide
#   alphas /= alpha_normalization_constant.reshape((1,1,conv_first_grad[0].shape[2]))
# 1 loop, best of 5: 470 ms per loop
# Score-Cam
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 1 loop, best of 5: 299 ms per loop
# Faster-Score-Cam N=10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 1 loop, best of 5: 208 ms per loop
# Faster-Score-Cam N=3
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 1 loop, best of 5: 200 ms per loop
# Guided-BP
# 1 loop, best of 5: 207 ms per loop

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import cv2
import numpy as np
from scorecamutil import GradCam, GradCamPlusPlus, ScoreCam, build_guided_model, GuidedBackPropagation, superimpose, read_and_preprocess_img

def build_Sequential_and_load():
    model = build_Sequential()
    model.load_weights('/content/trained_model_vgg_scorecam.h5')
    return model

img_path = '/content/drive/MyDrive/PlantVillage/Test/Tomato___Bacterial_spot/dbda016b-fd39-451d-82e5-08e42ea6bcda___GCREC_Bact.Sp 3285.JPG'
orig_img = np.array(load_img(img_path),dtype=np.uint8)
img_array = read_and_preprocess_img(img_path, size=(224,224))

layer_name = 'block1_conv2'

# predictions = model.predict(img_array)
# top = decode_predictions(predictions, top=5)[0]
# print(img_path)
# print("class activation map for:",top[0])

grad_cam=GradCam(model,img_array,layer_name)
grad_cam_superimposed = superimpose(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)

score_cam=ScoreCam(model,img_array,layer_name)
score_cam_superimposed = superimpose(img_path, score_cam)
score_cam_emphasized = superimpose(img_path, score_cam, emphasize=True)

faster_score_cam=ScoreCam(model,img_array,layer_name, max_N=10)
faster_score_cam_superimposed = superimpose(img_path, faster_score_cam)
faster_score_cam_emphasized = superimpose(img_path, faster_score_cam, emphasize=True)

guided_model = build_guided_model(build_Sequential_and_load)
saliency = GuidedBackPropagation(guided_model, img_array, layer_name)
saliency_resized = cv2.resize(saliency, (orig_img.shape[1], orig_img.shape[0]))

grad_cam_resized = cv2.resize(grad_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam = saliency_resized * grad_cam_resized[..., np.newaxis]

grad_cam_plus_plus_resized = cv2.resize(grad_cam_plus_plus, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam_plus_plus = saliency_resized * grad_cam_plus_plus_resized[..., np.newaxis]

score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_score_cam = saliency_resized * score_cam_resized[..., np.newaxis]

faster_score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_faster_score_cam = saliency_resized * faster_score_cam_resized[..., np.newaxis]

img_gray = cv2.imread(img_path, 0)
dx = cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=3)
dy = cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=3)
grad = np.sqrt(dx ** 2 + dy ** 2)  # 画像の勾配を取得
grad = cv2.dilate(grad,kernel=np.ones((5,5)), iterations=1)  # 太らせる処理
grad -= np.min(grad)
grad /= np.max(grad)  # scale 0. to 1.

grad_times_grad_cam = grad * grad_cam_resized
grad_times_grad_cam_plus_plus = grad * grad_cam_plus_plus_resized
grad_times_score_cam = grad * score_cam_resized
grad_times_faster_score_cam = grad * faster_score_cam_resized

fig, ax = plt.subplots(nrows=4,ncols=5, figsize=(18, 11))
ax[0,0].imshow(orig_img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam_superimposed)
ax[0,1].set_title("Grad-CAM")
ax[0,2].imshow(grad_cam_plus_plus_superimposed)
ax[0,2].set_title("Grad-CAM++")
ax[0,3].imshow(score_cam_superimposed)
ax[0,3].set_title("Score-CAM")
ax[0,4].imshow(faster_score_cam_superimposed)
ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(orig_img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_emphasized)
ax[1,1].set_title("Grad-CAM emphasized")
ax[1,2].imshow(grad_cam_plus_plus_emphasized)
ax[1,2].set_title("Grad-CAM++ emphasized")
ax[1,3].imshow(score_cam_emphasized)
ax[1,3].set_title("Score-CAM emphasized")
ax[1,4].imshow(faster_score_cam_emphasized)
ax[1,4].set_title("Faster-Score-CAM emphasized")
ax[2,0].imshow(saliency_resized)
ax[2,0].set_title("Guided-BP")
ax[2,1].imshow(guided_grad_cam)
ax[2,1].set_title("Guided-Grad-CAM")
ax[2,2].imshow(guided_grad_cam_plus_plus)
ax[2,2].set_title("Guided-Grad-CAM++")
ax[2,3].imshow(guided_score_cam)
ax[2,3].set_title("Guided-Score-CAM")
ax[2,4].imshow(guided_faster_score_cam)
ax[2,4].set_title("Guided-Faster-Score-CAM")
ax[3,0].imshow(grad, 'gray')
ax[3,0].set_title("grad")
ax[3,1].imshow(grad_times_grad_cam, 'gray')
ax[3,1].set_title("grad * Grad-CAM")
ax[3,2].imshow(grad_times_grad_cam_plus_plus, 'gray')
ax[3,2].set_title("grad * Grad-CAM++")
ax[3,3].imshow(grad_times_score_cam, 'gray')
ax[3,3].set_title("grad * Score-CAM")
ax[3,4].imshow(grad_times_faster_score_cam, 'gray')
ax[3,4].set_title("grad * Faster-Score-CAM")
for i in range(4):
    for j in range(5):
        ax[i,j].axis('off')
plt.show()
# Out:
# /content/scorecamutil.py:41: RuntimeWarning: invalid value encountered in true_divide
#   cam /= np.max(cam)  # scale 0 to 1.0
# /content/scorecamutil.py:67: RuntimeWarning: invalid value encountered in true_divide
#   alphas /= alpha_normalization_constant.reshape((1,1,conv_first_grad[0].shape[2]))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import cv2
import numpy as np
from scorecamutil import GradCam, GradCamPlusPlus, ScoreCam, build_guided_model, GuidedBackPropagation, superimpose, read_and_preprocess_img

def build_Sequential_and_load():
    model = build_Sequential()
    model.load_weights('/content/trained_model_vgg_scorecam.h5')
    return model

img_path = '/content/drive/MyDrive/PlantVillage/Test/Tomato___Bacterial_spot/dbda016b-fd39-451d-82e5-08e42ea6bcda___GCREC_Bact.Sp 3285.JPG'
orig_img = np.array(load_img(img_path),dtype=np.uint8)
img_array = read_and_preprocess_img(img_path, size=(224,224))

layer_name = 'block2_conv1'

# predictions = model.predict(img_array)
# top = decode_predictions(predictions, top=5)[0]
# print(img_path)
# print("class activation map for:",top[0])

grad_cam=GradCam(model,img_array,layer_name)
grad_cam_superimposed = superimpose(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)

score_cam=ScoreCam(model,img_array,layer_name)
score_cam_superimposed = superimpose(img_path, score_cam)
score_cam_emphasized = superimpose(img_path, score_cam, emphasize=True)

faster_score_cam=ScoreCam(model,img_array,layer_name, max_N=10)
faster_score_cam_superimposed = superimpose(img_path, faster_score_cam)
faster_score_cam_emphasized = superimpose(img_path, faster_score_cam, emphasize=True)

guided_model = build_guided_model(build_Sequential_and_load)
saliency = GuidedBackPropagation(guided_model, img_array, layer_name)
saliency_resized = cv2.resize(saliency, (orig_img.shape[1], orig_img.shape[0]))

grad_cam_resized = cv2.resize(grad_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam = saliency_resized * grad_cam_resized[..., np.newaxis]

grad_cam_plus_plus_resized = cv2.resize(grad_cam_plus_plus, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam_plus_plus = saliency_resized * grad_cam_plus_plus_resized[..., np.newaxis]

score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_score_cam = saliency_resized * score_cam_resized[..., np.newaxis]

faster_score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_faster_score_cam = saliency_resized * faster_score_cam_resized[..., np.newaxis]

img_gray = cv2.imread(img_path, 0)
dx = cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=3)
dy = cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=3)
grad = np.sqrt(dx ** 2 + dy ** 2)  # 画像の勾配を取得
grad = cv2.dilate(grad,kernel=np.ones((5,5)), iterations=1)  # 太らせる処理
grad -= np.min(grad)
grad /= np.max(grad)  # scale 0. to 1.

grad_times_grad_cam = grad * grad_cam_resized
grad_times_grad_cam_plus_plus = grad * grad_cam_plus_plus_resized
grad_times_score_cam = grad * score_cam_resized
grad_times_faster_score_cam = grad * faster_score_cam_resized

fig, ax = plt.subplots(nrows=4,ncols=5, figsize=(18, 11))
ax[0,0].imshow(orig_img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam_superimposed)
ax[0,1].set_title("Grad-CAM")
ax[0,2].imshow(grad_cam_plus_plus_superimposed)
ax[0,2].set_title("Grad-CAM++")
ax[0,3].imshow(score_cam_superimposed)
ax[0,3].set_title("Score-CAM")
ax[0,4].imshow(faster_score_cam_superimposed)
ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(orig_img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_emphasized)
ax[1,1].set_title("Grad-CAM emphasized")
ax[1,2].imshow(grad_cam_plus_plus_emphasized)
ax[1,2].set_title("Grad-CAM++ emphasized")
ax[1,3].imshow(score_cam_emphasized)
ax[1,3].set_title("Score-CAM emphasized")
ax[1,4].imshow(faster_score_cam_emphasized)
ax[1,4].set_title("Faster-Score-CAM emphasized")
ax[2,0].imshow(saliency_resized)
ax[2,0].set_title("Guided-BP")
ax[2,1].imshow(guided_grad_cam)
ax[2,1].set_title("Guided-Grad-CAM")
ax[2,2].imshow(guided_grad_cam_plus_plus)
ax[2,2].set_title("Guided-Grad-CAM++")
ax[2,3].imshow(guided_score_cam)
ax[2,3].set_title("Guided-Score-CAM")
ax[2,4].imshow(guided_faster_score_cam)
ax[2,4].set_title("Guided-Faster-Score-CAM")
ax[3,0].imshow(grad, 'gray')
ax[3,0].set_title("grad")
ax[3,1].imshow(grad_times_grad_cam, 'gray')
ax[3,1].set_title("grad * Grad-CAM")
ax[3,2].imshow(grad_times_grad_cam_plus_plus, 'gray')
ax[3,2].set_title("grad * Grad-CAM++")
ax[3,3].imshow(grad_times_score_cam, 'gray')
ax[3,3].set_title("grad * Score-CAM")
ax[3,4].imshow(grad_times_faster_score_cam, 'gray')
ax[3,4].set_title("grad * Faster-Score-CAM")
for i in range(4):
    for j in range(5):
        ax[i,j].axis('off')
plt.show()
# Out:
# /content/scorecamutil.py:41: RuntimeWarning: invalid value encountered in true_divide
#   cam /= np.max(cam)  # scale 0 to 1.0
# /content/scorecamutil.py:67: RuntimeWarning: invalid value encountered in true_divide
#   alphas /= alpha_normalization_constant.reshape((1,1,conv_first_grad[0].shape[2]))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import cv2
import numpy as np
from scorecamutil import GradCam, GradCamPlusPlus, ScoreCam, build_guided_model, GuidedBackPropagation, superimpose, read_and_preprocess_img

def build_Sequential_and_load():
    model = build_Sequential()
    model.load_weights('/content/trained_model_vgg_scorecam.h5')
    return model

img_path = '/content/drive/MyDrive/PlantVillage/Test/Tomato___Bacterial_spot/dbda016b-fd39-451d-82e5-08e42ea6bcda___GCREC_Bact.Sp 3285.JPG'
orig_img = np.array(load_img(img_path),dtype=np.uint8)
img_array = read_and_preprocess_img(img_path, size=(224,224))

layer_name = 'block2_conv2'

# predictions = model.predict(img_array)
# top = decode_predictions(predictions, top=5)[0]
# print(img_path)
# print("class activation map for:",top[0])

grad_cam=GradCam(model,img_array,layer_name)
grad_cam_superimposed = superimpose(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)

score_cam=ScoreCam(model,img_array,layer_name)
score_cam_superimposed = superimpose(img_path, score_cam)
score_cam_emphasized = superimpose(img_path, score_cam, emphasize=True)

faster_score_cam=ScoreCam(model,img_array,layer_name, max_N=10)
faster_score_cam_superimposed = superimpose(img_path, faster_score_cam)
faster_score_cam_emphasized = superimpose(img_path, faster_score_cam, emphasize=True)

guided_model = build_guided_model(build_Sequential_and_load)
saliency = GuidedBackPropagation(guided_model, img_array, layer_name)
saliency_resized = cv2.resize(saliency, (orig_img.shape[1], orig_img.shape[0]))

grad_cam_resized = cv2.resize(grad_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam = saliency_resized * grad_cam_resized[..., np.newaxis]

grad_cam_plus_plus_resized = cv2.resize(grad_cam_plus_plus, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam_plus_plus = saliency_resized * grad_cam_plus_plus_resized[..., np.newaxis]

score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_score_cam = saliency_resized * score_cam_resized[..., np.newaxis]

faster_score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_faster_score_cam = saliency_resized * faster_score_cam_resized[..., np.newaxis]

img_gray = cv2.imread(img_path, 0)
dx = cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=3)
dy = cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=3)
grad = np.sqrt(dx ** 2 + dy ** 2)  # 画像の勾配を取得
grad = cv2.dilate(grad,kernel=np.ones((5,5)), iterations=1)  # 太らせる処理
grad -= np.min(grad)
grad /= np.max(grad)  # scale 0. to 1.

grad_times_grad_cam = grad * grad_cam_resized
grad_times_grad_cam_plus_plus = grad * grad_cam_plus_plus_resized
grad_times_score_cam = grad * score_cam_resized
grad_times_faster_score_cam = grad * faster_score_cam_resized

fig, ax = plt.subplots(nrows=4,ncols=5, figsize=(18, 11))
ax[0,0].imshow(orig_img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam_superimposed)
ax[0,1].set_title("Grad-CAM")
ax[0,2].imshow(grad_cam_plus_plus_superimposed)
ax[0,2].set_title("Grad-CAM++")
ax[0,3].imshow(score_cam_superimposed)
ax[0,3].set_title("Score-CAM")
ax[0,4].imshow(faster_score_cam_superimposed)
ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(orig_img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_emphasized)
ax[1,1].set_title("Grad-CAM emphasized")
ax[1,2].imshow(grad_cam_plus_plus_emphasized)
ax[1,2].set_title("Grad-CAM++ emphasized")
ax[1,3].imshow(score_cam_emphasized)
ax[1,3].set_title("Score-CAM emphasized")
ax[1,4].imshow(faster_score_cam_emphasized)
ax[1,4].set_title("Faster-Score-CAM emphasized")
ax[2,0].imshow(saliency_resized)
ax[2,0].set_title("Guided-BP")
ax[2,1].imshow(guided_grad_cam)
ax[2,1].set_title("Guided-Grad-CAM")
ax[2,2].imshow(guided_grad_cam_plus_plus)
ax[2,2].set_title("Guided-Grad-CAM++")
ax[2,3].imshow(guided_score_cam)
ax[2,3].set_title("Guided-Score-CAM")
ax[2,4].imshow(guided_faster_score_cam)
ax[2,4].set_title("Guided-Faster-Score-CAM")
ax[3,0].imshow(grad, 'gray')
ax[3,0].set_title("grad")
ax[3,1].imshow(grad_times_grad_cam, 'gray')
ax[3,1].set_title("grad * Grad-CAM")
ax[3,2].imshow(grad_times_grad_cam_plus_plus, 'gray')
ax[3,2].set_title("grad * Grad-CAM++")
ax[3,3].imshow(grad_times_score_cam, 'gray')
ax[3,3].set_title("grad * Score-CAM")
ax[3,4].imshow(grad_times_faster_score_cam, 'gray')
ax[3,4].set_title("grad * Faster-Score-CAM")
for i in range(4):
    for j in range(5):
        ax[i,j].axis('off')
plt.show()
# Out:
# /content/scorecamutil.py:41: RuntimeWarning: invalid value encountered in true_divide
#   cam /= np.max(cam)  # scale 0 to 1.0
# /content/scorecamutil.py:67: RuntimeWarning: invalid value encountered in true_divide
#   alphas /= alpha_normalization_constant.reshape((1,1,conv_first_grad[0].shape[2]))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import cv2
import numpy as np
from scorecamutil import GradCam, GradCamPlusPlus, ScoreCam, build_guided_model, GuidedBackPropagation, superimpose, read_and_preprocess_img

def build_Sequential_and_load():
    model = build_Sequential()
    model.load_weights('/content/trained_model_vgg_scorecam.h5')
    return model

img_path = '/content/drive/MyDrive/PlantVillage/Test/Tomato___Bacterial_spot/dbda016b-fd39-451d-82e5-08e42ea6bcda___GCREC_Bact.Sp 3285.JPG'
orig_img = np.array(load_img(img_path),dtype=np.uint8)
img_array = read_and_preprocess_img(img_path, size=(224,224))

layer_name = 'block3_conv1'

# predictions = model.predict(img_array)
# top = decode_predictions(predictions, top=5)[0]
# print(img_path)
# print("class activation map for:",top[0])

grad_cam=GradCam(model,img_array,layer_name)
grad_cam_superimposed = superimpose(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)

score_cam=ScoreCam(model,img_array,layer_name)
score_cam_superimposed = superimpose(img_path, score_cam)
score_cam_emphasized = superimpose(img_path, score_cam, emphasize=True)

faster_score_cam=ScoreCam(model,img_array,layer_name, max_N=10)
faster_score_cam_superimposed = superimpose(img_path, faster_score_cam)
faster_score_cam_emphasized = superimpose(img_path, faster_score_cam, emphasize=True)

guided_model = build_guided_model(build_Sequential_and_load)
saliency = GuidedBackPropagation(guided_model, img_array, layer_name)
saliency_resized = cv2.resize(saliency, (orig_img.shape[1], orig_img.shape[0]))

grad_cam_resized = cv2.resize(grad_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam = saliency_resized * grad_cam_resized[..., np.newaxis]

grad_cam_plus_plus_resized = cv2.resize(grad_cam_plus_plus, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam_plus_plus = saliency_resized * grad_cam_plus_plus_resized[..., np.newaxis]

score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_score_cam = saliency_resized * score_cam_resized[..., np.newaxis]

faster_score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_faster_score_cam = saliency_resized * faster_score_cam_resized[..., np.newaxis]

img_gray = cv2.imread(img_path, 0)
dx = cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=3)
dy = cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=3)
grad = np.sqrt(dx ** 2 + dy ** 2)  # 画像の勾配を取得
grad = cv2.dilate(grad,kernel=np.ones((5,5)), iterations=1)  # 太らせる処理
grad -= np.min(grad)
grad /= np.max(grad)  # scale 0. to 1.

grad_times_grad_cam = grad * grad_cam_resized
grad_times_grad_cam_plus_plus = grad * grad_cam_plus_plus_resized
grad_times_score_cam = grad * score_cam_resized
grad_times_faster_score_cam = grad * faster_score_cam_resized

fig, ax = plt.subplots(nrows=4,ncols=5, figsize=(18, 11))
ax[0,0].imshow(orig_img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam_superimposed)
ax[0,1].set_title("Grad-CAM")
ax[0,2].imshow(grad_cam_plus_plus_superimposed)
ax[0,2].set_title("Grad-CAM++")
ax[0,3].imshow(score_cam_superimposed)
ax[0,3].set_title("Score-CAM")
ax[0,4].imshow(faster_score_cam_superimposed)
ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(orig_img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_emphasized)
ax[1,1].set_title("Grad-CAM emphasized")
ax[1,2].imshow(grad_cam_plus_plus_emphasized)
ax[1,2].set_title("Grad-CAM++ emphasized")
ax[1,3].imshow(score_cam_emphasized)
ax[1,3].set_title("Score-CAM emphasized")
ax[1,4].imshow(faster_score_cam_emphasized)
ax[1,4].set_title("Faster-Score-CAM emphasized")
ax[2,0].imshow(saliency_resized)
ax[2,0].set_title("Guided-BP")
ax[2,1].imshow(guided_grad_cam)
ax[2,1].set_title("Guided-Grad-CAM")
ax[2,2].imshow(guided_grad_cam_plus_plus)
ax[2,2].set_title("Guided-Grad-CAM++")
ax[2,3].imshow(guided_score_cam)
ax[2,3].set_title("Guided-Score-CAM")
ax[2,4].imshow(guided_faster_score_cam)
ax[2,4].set_title("Guided-Faster-Score-CAM")
ax[3,0].imshow(grad, 'gray')
ax[3,0].set_title("grad")
ax[3,1].imshow(grad_times_grad_cam, 'gray')
ax[3,1].set_title("grad * Grad-CAM")
ax[3,2].imshow(grad_times_grad_cam_plus_plus, 'gray')
ax[3,2].set_title("grad * Grad-CAM++")
ax[3,3].imshow(grad_times_score_cam, 'gray')
ax[3,3].set_title("grad * Score-CAM")
ax[3,4].imshow(grad_times_faster_score_cam, 'gray')
ax[3,4].set_title("grad * Faster-Score-CAM")
for i in range(4):
    for j in range(5):
        ax[i,j].axis('off')
plt.show()
# Out:
# /content/scorecamutil.py:41: RuntimeWarning: invalid value encountered in true_divide
#   cam /= np.max(cam)  # scale 0 to 1.0
# /content/scorecamutil.py:67: RuntimeWarning: invalid value encountered in true_divide
#   alphas /= alpha_normalization_constant.reshape((1,1,conv_first_grad[0].shape[2]))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import cv2
import numpy as np
from scorecamutil import GradCam, GradCamPlusPlus, ScoreCam, build_guided_model, GuidedBackPropagation, superimpose, read_and_preprocess_img

def build_Sequential_and_load():
    model = build_Sequential()
    model.load_weights('/content/trained_model_vgg_scorecam.h5')
    return model

img_path = '/content/drive/MyDrive/PlantVillage/Test/Tomato___Bacterial_spot/dbda016b-fd39-451d-82e5-08e42ea6bcda___GCREC_Bact.Sp 3285.JPG'
orig_img = np.array(load_img(img_path),dtype=np.uint8)
img_array = read_and_preprocess_img(img_path, size=(224,224))

layer_name = 'block3_conv2'

# predictions = model.predict(img_array)
# top = decode_predictions(predictions, top=5)[0]
# print(img_path)
# print("class activation map for:",top[0])

grad_cam=GradCam(model,img_array,layer_name)
grad_cam_superimposed = superimpose(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)

score_cam=ScoreCam(model,img_array,layer_name)
score_cam_superimposed = superimpose(img_path, score_cam)
score_cam_emphasized = superimpose(img_path, score_cam, emphasize=True)

faster_score_cam=ScoreCam(model,img_array,layer_name, max_N=10)
faster_score_cam_superimposed = superimpose(img_path, faster_score_cam)
faster_score_cam_emphasized = superimpose(img_path, faster_score_cam, emphasize=True)

guided_model = build_guided_model(build_Sequential_and_load)
saliency = GuidedBackPropagation(guided_model, img_array, layer_name)
saliency_resized = cv2.resize(saliency, (orig_img.shape[1], orig_img.shape[0]))

grad_cam_resized = cv2.resize(grad_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam = saliency_resized * grad_cam_resized[..., np.newaxis]

grad_cam_plus_plus_resized = cv2.resize(grad_cam_plus_plus, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam_plus_plus = saliency_resized * grad_cam_plus_plus_resized[..., np.newaxis]

score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_score_cam = saliency_resized * score_cam_resized[..., np.newaxis]

faster_score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_faster_score_cam = saliency_resized * faster_score_cam_resized[..., np.newaxis]

img_gray = cv2.imread(img_path, 0)
dx = cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=3)
dy = cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=3)
grad = np.sqrt(dx ** 2 + dy ** 2)  # 画像の勾配を取得
grad = cv2.dilate(grad,kernel=np.ones((5,5)), iterations=1)  # 太らせる処理
grad -= np.min(grad)
grad /= np.max(grad)  # scale 0. to 1.

grad_times_grad_cam = grad * grad_cam_resized
grad_times_grad_cam_plus_plus = grad * grad_cam_plus_plus_resized
grad_times_score_cam = grad * score_cam_resized
grad_times_faster_score_cam = grad * faster_score_cam_resized

fig, ax = plt.subplots(nrows=4,ncols=5, figsize=(18, 11))
ax[0,0].imshow(orig_img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam_superimposed)
ax[0,1].set_title("Grad-CAM")
ax[0,2].imshow(grad_cam_plus_plus_superimposed)
ax[0,2].set_title("Grad-CAM++")
ax[0,3].imshow(score_cam_superimposed)
ax[0,3].set_title("Score-CAM")
ax[0,4].imshow(faster_score_cam_superimposed)
ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(orig_img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_emphasized)
ax[1,1].set_title("Grad-CAM emphasized")
ax[1,2].imshow(grad_cam_plus_plus_emphasized)
ax[1,2].set_title("Grad-CAM++ emphasized")
ax[1,3].imshow(score_cam_emphasized)
ax[1,3].set_title("Score-CAM emphasized")
ax[1,4].imshow(faster_score_cam_emphasized)
ax[1,4].set_title("Faster-Score-CAM emphasized")
ax[2,0].imshow(saliency_resized)
ax[2,0].set_title("Guided-BP")
ax[2,1].imshow(guided_grad_cam)
ax[2,1].set_title("Guided-Grad-CAM")
ax[2,2].imshow(guided_grad_cam_plus_plus)
ax[2,2].set_title("Guided-Grad-CAM++")
ax[2,3].imshow(guided_score_cam)
ax[2,3].set_title("Guided-Score-CAM")
ax[2,4].imshow(guided_faster_score_cam)
ax[2,4].set_title("Guided-Faster-Score-CAM")
ax[3,0].imshow(grad, 'gray')
ax[3,0].set_title("grad")
ax[3,1].imshow(grad_times_grad_cam, 'gray')
ax[3,1].set_title("grad * Grad-CAM")
ax[3,2].imshow(grad_times_grad_cam_plus_plus, 'gray')
ax[3,2].set_title("grad * Grad-CAM++")
ax[3,3].imshow(grad_times_score_cam, 'gray')
ax[3,3].set_title("grad * Score-CAM")
ax[3,4].imshow(grad_times_faster_score_cam, 'gray')
ax[3,4].set_title("grad * Faster-Score-CAM")
for i in range(4):
    for j in range(5):
        ax[i,j].axis('off')
plt.show()
# Out:
# /content/scorecamutil.py:41: RuntimeWarning: invalid value encountered in true_divide
#   cam /= np.max(cam)  # scale 0 to 1.0
# /content/scorecamutil.py:67: RuntimeWarning: invalid value encountered in true_divide
#   alphas /= alpha_normalization_constant.reshape((1,1,conv_first_grad[0].shape[2]))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import cv2
import numpy as np
from scorecamutil import GradCam, GradCamPlusPlus, ScoreCam, build_guided_model, GuidedBackPropagation, superimpose, read_and_preprocess_img

def build_Sequential_and_load():
    model = build_Sequential()
    model.load_weights('/content/trained_model_vgg_scorecam.h5')
    return model

img_path = '/content/drive/MyDrive/PlantVillage/Test/Tomato___Bacterial_spot/dbda016b-fd39-451d-82e5-08e42ea6bcda___GCREC_Bact.Sp 3285.JPG'
orig_img = np.array(load_img(img_path),dtype=np.uint8)
img_array = read_and_preprocess_img(img_path, size=(224,224))

layer_name = 'block3_conv3'

# predictions = model.predict(img_array)
# top = decode_predictions(predictions, top=5)[0]
# print(img_path)
# print("class activation map for:",top[0])

grad_cam=GradCam(model,img_array,layer_name)
grad_cam_superimposed = superimpose(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)

score_cam=ScoreCam(model,img_array,layer_name)
score_cam_superimposed = superimpose(img_path, score_cam)
score_cam_emphasized = superimpose(img_path, score_cam, emphasize=True)

faster_score_cam=ScoreCam(model,img_array,layer_name, max_N=10)
faster_score_cam_superimposed = superimpose(img_path, faster_score_cam)
faster_score_cam_emphasized = superimpose(img_path, faster_score_cam, emphasize=True)

guided_model = build_guided_model(build_Sequential_and_load)
saliency = GuidedBackPropagation(guided_model, img_array, layer_name)
saliency_resized = cv2.resize(saliency, (orig_img.shape[1], orig_img.shape[0]))

grad_cam_resized = cv2.resize(grad_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam = saliency_resized * grad_cam_resized[..., np.newaxis]

grad_cam_plus_plus_resized = cv2.resize(grad_cam_plus_plus, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam_plus_plus = saliency_resized * grad_cam_plus_plus_resized[..., np.newaxis]

score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_score_cam = saliency_resized * score_cam_resized[..., np.newaxis]

faster_score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_faster_score_cam = saliency_resized * faster_score_cam_resized[..., np.newaxis]

img_gray = cv2.imread(img_path, 0)
dx = cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=3)
dy = cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=3)
grad = np.sqrt(dx ** 2 + dy ** 2)  # 画像の勾配を取得
grad = cv2.dilate(grad,kernel=np.ones((5,5)), iterations=1)  # 太らせる処理
grad -= np.min(grad)
grad /= np.max(grad)  # scale 0. to 1.

grad_times_grad_cam = grad * grad_cam_resized
grad_times_grad_cam_plus_plus = grad * grad_cam_plus_plus_resized
grad_times_score_cam = grad * score_cam_resized
grad_times_faster_score_cam = grad * faster_score_cam_resized

fig, ax = plt.subplots(nrows=4,ncols=5, figsize=(18, 11))
ax[0,0].imshow(orig_img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam_superimposed)
ax[0,1].set_title("Grad-CAM")
ax[0,2].imshow(grad_cam_plus_plus_superimposed)
ax[0,2].set_title("Grad-CAM++")
ax[0,3].imshow(score_cam_superimposed)
ax[0,3].set_title("Score-CAM")
ax[0,4].imshow(faster_score_cam_superimposed)
ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(orig_img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_emphasized)
ax[1,1].set_title("Grad-CAM emphasized")
ax[1,2].imshow(grad_cam_plus_plus_emphasized)
ax[1,2].set_title("Grad-CAM++ emphasized")
ax[1,3].imshow(score_cam_emphasized)
ax[1,3].set_title("Score-CAM emphasized")
ax[1,4].imshow(faster_score_cam_emphasized)
ax[1,4].set_title("Faster-Score-CAM emphasized")
ax[2,0].imshow(saliency_resized)
ax[2,0].set_title("Guided-BP")
ax[2,1].imshow(guided_grad_cam)
ax[2,1].set_title("Guided-Grad-CAM")
ax[2,2].imshow(guided_grad_cam_plus_plus)
ax[2,2].set_title("Guided-Grad-CAM++")
ax[2,3].imshow(guided_score_cam)
ax[2,3].set_title("Guided-Score-CAM")
ax[2,4].imshow(guided_faster_score_cam)
ax[2,4].set_title("Guided-Faster-Score-CAM")
ax[3,0].imshow(grad, 'gray')
ax[3,0].set_title("grad")
ax[3,1].imshow(grad_times_grad_cam, 'gray')
ax[3,1].set_title("grad * Grad-CAM")
ax[3,2].imshow(grad_times_grad_cam_plus_plus, 'gray')
ax[3,2].set_title("grad * Grad-CAM++")
ax[3,3].imshow(grad_times_score_cam, 'gray')
ax[3,3].set_title("grad * Score-CAM")
ax[3,4].imshow(grad_times_faster_score_cam, 'gray')
ax[3,4].set_title("grad * Faster-Score-CAM")
for i in range(4):
    for j in range(5):
        ax[i,j].axis('off')
plt.show()
# Out:
# /content/scorecamutil.py:41: RuntimeWarning: invalid value encountered in true_divide
#   cam /= np.max(cam)  # scale 0 to 1.0
# /content/scorecamutil.py:67: RuntimeWarning: invalid value encountered in true_divide
#   alphas /= alpha_normalization_constant.reshape((1,1,conv_first_grad[0].shape[2]))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import cv2
import numpy as np
from scorecamutil import GradCam, GradCamPlusPlus, ScoreCam, build_guided_model, GuidedBackPropagation, superimpose, read_and_preprocess_img

def build_Sequential_and_load():
    model = build_Sequential()
    model.load_weights('/content/trained_model_vgg_scorecam.h5')
    return model

img_path = '/content/drive/MyDrive/PlantVillage/Test/Tomato___Bacterial_spot/dbda016b-fd39-451d-82e5-08e42ea6bcda___GCREC_Bact.Sp 3285.JPG'
orig_img = np.array(load_img(img_path),dtype=np.uint8)
img_array = read_and_preprocess_img(img_path, size=(224,224))

layer_name = 'block5_conv1'

# predictions = model.predict(img_array)
# top = decode_predictions(predictions, top=5)[0]
# print(img_path)
# print("class activation map for:",top[0])

grad_cam=GradCam(model,img_array,layer_name)
grad_cam_superimposed = superimpose(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)

score_cam=ScoreCam(model,img_array,layer_name)
score_cam_superimposed = superimpose(img_path, score_cam)
score_cam_emphasized = superimpose(img_path, score_cam, emphasize=True)

faster_score_cam=ScoreCam(model,img_array,layer_name, max_N=10)
faster_score_cam_superimposed = superimpose(img_path, faster_score_cam)
faster_score_cam_emphasized = superimpose(img_path, faster_score_cam, emphasize=True)

guided_model = build_guided_model(build_Sequential_and_load)
saliency = GuidedBackPropagation(guided_model, img_array, layer_name)
saliency_resized = cv2.resize(saliency, (orig_img.shape[1], orig_img.shape[0]))

grad_cam_resized = cv2.resize(grad_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam = saliency_resized * grad_cam_resized[..., np.newaxis]

grad_cam_plus_plus_resized = cv2.resize(grad_cam_plus_plus, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam_plus_plus = saliency_resized * grad_cam_plus_plus_resized[..., np.newaxis]

score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_score_cam = saliency_resized * score_cam_resized[..., np.newaxis]

faster_score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_faster_score_cam = saliency_resized * faster_score_cam_resized[..., np.newaxis]

img_gray = cv2.imread(img_path, 0)
dx = cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=3)
dy = cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=3)
grad = np.sqrt(dx ** 2 + dy ** 2)  # 画像の勾配を取得
grad = cv2.dilate(grad,kernel=np.ones((5,5)), iterations=1)  # 太らせる処理
grad -= np.min(grad)
grad /= np.max(grad)  # scale 0. to 1.

grad_times_grad_cam = grad * grad_cam_resized
grad_times_grad_cam_plus_plus = grad * grad_cam_plus_plus_resized
grad_times_score_cam = grad * score_cam_resized
grad_times_faster_score_cam = grad * faster_score_cam_resized

fig, ax = plt.subplots(nrows=4,ncols=5, figsize=(18, 11))
ax[0,0].imshow(orig_img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam_superimposed)
ax[0,1].set_title("Grad-CAM")
ax[0,2].imshow(grad_cam_plus_plus_superimposed)
ax[0,2].set_title("Grad-CAM++")
ax[0,3].imshow(score_cam_superimposed)
ax[0,3].set_title("Score-CAM")
ax[0,4].imshow(faster_score_cam_superimposed)
ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(orig_img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_emphasized)
ax[1,1].set_title("Grad-CAM emphasized")
ax[1,2].imshow(grad_cam_plus_plus_emphasized)
ax[1,2].set_title("Grad-CAM++ emphasized")
ax[1,3].imshow(score_cam_emphasized)
ax[1,3].set_title("Score-CAM emphasized")
ax[1,4].imshow(faster_score_cam_emphasized)
ax[1,4].set_title("Faster-Score-CAM emphasized")
ax[2,0].imshow(saliency_resized)
ax[2,0].set_title("Guided-BP")
ax[2,1].imshow(guided_grad_cam)
ax[2,1].set_title("Guided-Grad-CAM")
ax[2,2].imshow(guided_grad_cam_plus_plus)
ax[2,2].set_title("Guided-Grad-CAM++")
ax[2,3].imshow(guided_score_cam)
ax[2,3].set_title("Guided-Score-CAM")
ax[2,4].imshow(guided_faster_score_cam)
ax[2,4].set_title("Guided-Faster-Score-CAM")
ax[3,0].imshow(grad, 'gray')
ax[3,0].set_title("grad")
ax[3,1].imshow(grad_times_grad_cam, 'gray')
ax[3,1].set_title("grad * Grad-CAM")
ax[3,2].imshow(grad_times_grad_cam_plus_plus, 'gray')
ax[3,2].set_title("grad * Grad-CAM++")
ax[3,3].imshow(grad_times_score_cam, 'gray')
ax[3,3].set_title("grad * Score-CAM")
ax[3,4].imshow(grad_times_faster_score_cam, 'gray')
ax[3,4].set_title("grad * Faster-Score-CAM")
for i in range(4):
    for j in range(5):
        ax[i,j].axis('off')
plt.show()
# Out:
# /content/scorecamutil.py:41: RuntimeWarning: invalid value encountered in true_divide
#   cam /= np.max(cam)  # scale 0 to 1.0
# /content/scorecamutil.py:67: RuntimeWarning: invalid value encountered in true_divide
#   alphas /= alpha_normalization_constant.reshape((1,1,conv_first_grad[0].shape[2]))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import cv2
import numpy as np
from scorecamutil import GradCam, GradCamPlusPlus, ScoreCam, build_guided_model, GuidedBackPropagation, superimpose, read_and_preprocess_img

def build_Sequential_and_load():
    model = build_Sequential()
    model.load_weights('/content/trained_model_vgg_scorecam.h5')
    return model

img_path = '/content/drive/MyDrive/PlantVillage/Test/Tomato___Bacterial_spot/dbda016b-fd39-451d-82e5-08e42ea6bcda___GCREC_Bact.Sp 3285.JPG'
orig_img = np.array(load_img(img_path),dtype=np.uint8)
img_array = read_and_preprocess_img(img_path, size=(224,224))

layer_name = 'block5_conv3'

# predictions = model.predict(img_array)
# top = decode_predictions(predictions, top=5)[0]
# print(img_path)
# print("class activation map for:",top[0])

grad_cam=GradCam(model,img_array,layer_name)
grad_cam_superimposed = superimpose(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)

score_cam=ScoreCam(model,img_array,layer_name)
score_cam_superimposed = superimpose(img_path, score_cam)
score_cam_emphasized = superimpose(img_path, score_cam, emphasize=True)

faster_score_cam=ScoreCam(model,img_array,layer_name, max_N=10)
faster_score_cam_superimposed = superimpose(img_path, faster_score_cam)
faster_score_cam_emphasized = superimpose(img_path, faster_score_cam, emphasize=True)

guided_model = build_guided_model(build_Sequential_and_load)
saliency = GuidedBackPropagation(guided_model, img_array, layer_name)
saliency_resized = cv2.resize(saliency, (orig_img.shape[1], orig_img.shape[0]))

grad_cam_resized = cv2.resize(grad_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam = saliency_resized * grad_cam_resized[..., np.newaxis]

grad_cam_plus_plus_resized = cv2.resize(grad_cam_plus_plus, (orig_img.shape[1], orig_img.shape[0]))
guided_grad_cam_plus_plus = saliency_resized * grad_cam_plus_plus_resized[..., np.newaxis]

score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_score_cam = saliency_resized * score_cam_resized[..., np.newaxis]

faster_score_cam_resized = cv2.resize(score_cam, (orig_img.shape[1], orig_img.shape[0]))
guided_faster_score_cam = saliency_resized * faster_score_cam_resized[..., np.newaxis]

img_gray = cv2.imread(img_path, 0)
dx = cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=3)
dy = cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=3)
grad = np.sqrt(dx ** 2 + dy ** 2)  # 画像の勾配を取得
grad = cv2.dilate(grad,kernel=np.ones((5,5)), iterations=1)  # 太らせる処理
grad -= np.min(grad)
grad /= np.max(grad)  # scale 0. to 1.

grad_times_grad_cam = grad * grad_cam_resized
grad_times_grad_cam_plus_plus = grad * grad_cam_plus_plus_resized
grad_times_score_cam = grad * score_cam_resized
grad_times_faster_score_cam = grad * faster_score_cam_resized

fig, ax = plt.subplots(nrows=4,ncols=5, figsize=(18, 11))
ax[0,0].imshow(orig_img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam_superimposed)
ax[0,1].set_title("Grad-CAM")
ax[0,2].imshow(grad_cam_plus_plus_superimposed)
ax[0,2].set_title("Grad-CAM++")
ax[0,3].imshow(score_cam_superimposed)
ax[0,3].set_title("Score-CAM")
ax[0,4].imshow(faster_score_cam_superimposed)
ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(orig_img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_emphasized)
ax[1,1].set_title("Grad-CAM emphasized")
ax[1,2].imshow(grad_cam_plus_plus_emphasized)
ax[1,2].set_title("Grad-CAM++ emphasized")
ax[1,3].imshow(score_cam_emphasized)
ax[1,3].set_title("Score-CAM emphasized")
ax[1,4].imshow(faster_score_cam_emphasized)
ax[1,4].set_title("Faster-Score-CAM emphasized")
ax[2,0].imshow(saliency_resized)
ax[2,0].set_title("Guided-BP")
ax[2,1].imshow(guided_grad_cam)
ax[2,1].set_title("Guided-Grad-CAM")
ax[2,2].imshow(guided_grad_cam_plus_plus)
ax[2,2].set_title("Guided-Grad-CAM++")
ax[2,3].imshow(guided_score_cam)
ax[2,3].set_title("Guided-Score-CAM")
ax[2,4].imshow(guided_faster_score_cam)
ax[2,4].set_title("Guided-Faster-Score-CAM")
ax[3,0].imshow(grad, 'gray')
ax[3,0].set_title("grad")
ax[3,1].imshow(grad_times_grad_cam, 'gray')
ax[3,1].set_title("grad * Grad-CAM")
ax[3,2].imshow(grad_times_grad_cam_plus_plus, 'gray')
ax[3,2].set_title("grad * Grad-CAM++")
ax[3,3].imshow(grad_times_score_cam, 'gray')
ax[3,3].set_title("grad * Score-CAM")
ax[3,4].imshow(grad_times_faster_score_cam, 'gray')
ax[3,4].set_title("grad * Faster-Score-CAM")
for i in range(4):
    for j in range(5):
        ax[i,j].axis('off')
plt.show()
# Out:
# /content/scorecamutil.py:41: RuntimeWarning: invalid value encountered in true_divide
#   cam /= np.max(cam)  # scale 0 to 1.0
# /content/scorecamutil.py:67: RuntimeWarning: invalid value encountered in true_divide
#   alphas /= alpha_normalization_constant.reshape((1,1,conv_first_grad[0].shape[2]))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
img_path = '/content/drive/MyDrive/PlantVillage/Train/Tomato___Early_blight/004cbe60-8ff9-4965-92df-e86694d5e9ba___RS_Erly.B 8253.JPG'

# We preprocess the image into a 4D tensor
from keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
# Remember that the model was trained on inputs
# that were preprocessed in the following way:
img_tensor /= 255.

plt.imshow(img_tensor[0])
plt.show()

# Its shape is (1, 150, 150, 3)
print(img_tensor.shape)
# Out:
# (1, 224, 224, 3)

# %%
from keras import models

layer_outputs = [layer.output for layer in model.layers[:36]] # Extracts the outputs of the top 12 layers
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.imshow(img_tensor[0])
plt.show()

# %%
from keras import models

# Extracts the outputs of the top 8 layers:
layer_outputs = [layer.output for layer in model.layers[1:]]
# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# %%
# This will return a list of 5 Numpy arrays:
# one array per layer activation
activations = activation_model.predict(img_tensor)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %%
first_layer_activation = activations[0]
print(first_layer_activation.shape)
# Out:
# (1, 226, 226, 3)

# %%
import matplotlib.pyplot as plt

plt.matshow(first_layer_activation[0, :, :, 1], cmap='viridis')
plt.show()

# %%
plt.matshow(first_layer_activation[0, :, :, 2], cmap='viridis')
plt.show()
