# %%
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import Adam
import numpy as np
from matplotlib import pyplot as plt
from keras.models import Model
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD
import numpy as np
from matplotlib import pyplot as plt
from keras.models import Model

# %%
# Load the dataset
data_path = '/content/drive/MyDrive/Phd_Data_set_Implementation/Aug-Training-four'

train_datagen = ImageDataGenerator(rescale=1./255)
train_datagenerator = train_datagen.flow_from_directory(
    data_path,
    target_size=(32, 32),
    class_mode='categorical',
    batch_size=32
)

test_data_path = '/content/drive/MyDrive/Phd_Data_set_Implementation/TESTING-FOUR-CLASSES-by-dec20'

test_datagen = ImageDataGenerator(rescale=1./255)
test_datagenerator = test_datagen.flow_from_directory(
    test_data_path,
    target_size=(32, 32),
    class_mode='categorical',
    batch_size=32
)
# Out:
# Found 9645 images belonging to 4 classes.
# Found 45 images belonging to 4 classes.

# %%
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(224, 224, 3)))
model.add(Convolution2D(64, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2), padding= 'same'))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2), padding='same'))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2), padding='same'))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2), padding='same'))

model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'],

)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 226, 226, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 75, 75, 64)        1792
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 77, 77, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 128)         147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 256)         295168
# _________________________________________________________________
# zero_padding2d_5 (ZeroPaddin (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 1, 256)         590080
# _________________________________________________________________
# zero_padding2d_6 (ZeroPaddin (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 1, 256)         590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# zero_padding2d_7 (ZeroPaddin (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 512)         1180160
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1, 1, 512)         2359808
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 512)         2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# zero_padding2d_10 (ZeroPaddi (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 1, 512)         2359808
# _________________________________________________________________
# zero_padding2d_11 (ZeroPaddi (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 1, 1, 512)         2359808
# _________________________________________________________________
# zero_padding2d_12 (ZeroPaddi (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 1, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 16388
# =================================================================
# Total params: 33,613,636
# Trainable params: 33,613,636
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy
from numpy.random import seed
seed(0)

history = model.fit(train_datagenerator, epochs=100, steps_per_epoch=16, validation_data=test_datagenerator)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 147s 9s/step - loss: 1.3875 - accuracy: 0.2871 - val_loss: 1.3794 - val_accuracy: 0.3333
# Epoch 2/100
# 16/16 [==============================] - 139s 9s/step - loss: 1.3938 - accuracy: 0.1909 - val_loss: 1.3850 - val_accuracy: 0.2222
# Epoch 3/100
# 16/16 [==============================] - 122s 8s/step - loss: 1.3856 - accuracy: 0.2246 - val_loss: 1.3863 - val_accuracy: 0.2222
# Epoch 4/100
# 16/16 [==============================] - 122s 7s/step - loss: 1.3855 - accuracy: 0.2639 - val_loss: 1.3813 - val_accuracy: 0.3333
# Epoch 5/100
# 16/16 [==============================] - 103s 6s/step - loss: 1.3902 - accuracy: 0.2732 - val_loss: 1.3788 - val_accuracy: 0.3333
# Epoch 6/100
# 16/16 [==============================] - 174s 11s/step - loss: 1.3831 - accuracy: 0.2842 - val_loss: 1.3721 - val_accuracy: 0.3333
# Epoch 7/100
# 16/16 [==============================] - 100s 6s/step - loss: 1.3861 - accuracy: 0.2855 - val_loss: 1.3711 - val_accuracy: 0.3333
# Epoch 8/100
# 16/16 [==============================] - 86s 5s/step - loss: 1.3699 - accuracy: 0.3306 - val_loss: 1.3694 - val_accuracy: 0.3333
# Epoch 9/100
# 16/16 [==============================] - 76s 5s/step - loss: 1.3853 - accuracy: 0.2758 - val_loss: 1.3797 - val_accuracy: 0.3333
# Epoch 10/100
# 16/16 [==============================] - 73s 4s/step - loss: 1.3892 - accuracy: 0.2407 - val_loss: 1.3832 - val_accuracy: 0.2222
# Epoch 11/100
# 16/16 [==============================] - 69s 4s/step - loss: 1.3914 - accuracy: 0.2277 - val_loss: 1.3796 - val_accuracy: 0.3333
# Epoch 12/100
# 16/16 [==============================] - 66s 4s/step - loss: 1.3868 - accuracy: 0.2689 - val_loss: 1.3807 - val_accuracy: 0.3333
# Epoch 13/100
# 16/16 [==============================] - 96s 6s/step - loss: 1.3824 - accuracy: 0.2583 - val_loss: 1.3814 - val_accuracy: 0.3333
# Epoch 14/100
# 16/16 [==============================] - 60s 4s/step - loss: 1.3931 - accuracy: 0.3216 - val_loss: 1.3715 - val_accuracy: 0.3333
# Epoch 15/100
# 16/16 [==============================] - 59s 4s/step - loss: 1.3840 - accuracy: 0.2808 - val_loss: 1.3719 - val_accuracy: 0.3333
# Epoch 16/100
# 16/16 [==============================] - 53s 3s/step - loss: 1.3768 - accuracy: 0.3100 - val_loss: 1.3721 - val_accuracy: 0.3333
# Epoch 17/100
# 16/16 [==============================] - 63s 4s/step - loss: 1.3840 - accuracy: 0.2888 - val_loss: 1.3737 - val_accuracy: 0.3333
# Epoch 18/100
# 16/16 [==============================] - 45s 3s/step - loss: 1.3852 - accuracy: 0.2780 - val_loss: 1.3740 - val_accuracy: 0.3333
# Epoch 19/100
# 16/16 [==============================] - 50s 3s/step - loss: 1.3825 - accuracy: 0.2876 - val_loss: 1.3748 - val_accuracy: 0.3333
# Epoch 20/100
# 16/16 [==============================] - 44s 3s/step - loss: 1.3919 - accuracy: 0.2281 - val_loss: 1.3791 - val_accuracy: 0.3333
# Epoch 21/100
# 16/16 [==============================] - 40s 2s/step - loss: 1.3799 - accuracy: 0.3197 - val_loss: 1.3769 - val_accuracy: 0.3333
# Epoch 22/100
# 16/16 [==============================] - 43s 3s/step - loss: 1.3918 - accuracy: 0.2599 - val_loss: 1.3775 - val_accuracy: 0.3333
# Epoch 23/100
# 16/16 [==============================] - 118s 8s/step - loss: 1.3842 - accuracy: 0.2912 - val_loss: 1.3764 - val_accuracy: 0.3333
# Epoch 24/100
# 16/16 [==============================] - 64s 4s/step - loss: 1.3853 - accuracy: 0.2845 - val_loss: 1.3759 - val_accuracy: 0.3333
# Epoch 25/100
# 16/16 [==============================] - 70s 3s/step - loss: 1.3821 - accuracy: 0.2776 - val_loss: 1.3769 - val_accuracy: 0.3333
# Epoch 26/100
# 16/16 [==============================] - 34s 2s/step - loss: 1.3760 - accuracy: 0.3142 - val_loss: 1.3758 - val_accuracy: 0.3333
# Epoch 27/100
# 16/16 [==============================] - 32s 2s/step - loss: 1.3854 - accuracy: 0.2910 - val_loss: 1.3738 - val_accuracy: 0.3333
# Epoch 28/100
# 16/16 [==============================] - 31s 2s/step - loss: 1.3866 - accuracy: 0.2782 - val_loss: 1.3736 - val_accuracy: 0.3333
# Epoch 29/100
# 16/16 [==============================] - 31s 2s/step - loss: 1.3728 - accuracy: 0.3389 - val_loss: 1.3709 - val_accuracy: 0.3333
# Epoch 30/100
# 16/16 [==============================] - 28s 2s/step - loss: 1.3949 - accuracy: 0.2504 - val_loss: 1.3738 - val_accuracy: 0.3333
# Epoch 31/100
# 16/16 [==============================] - 30s 2s/step - loss: 1.3922 - accuracy: 0.2433 - val_loss: 1.3764 - val_accuracy: 0.3333
# Epoch 32/100
# 16/16 [==============================] - 34s 2s/step - loss: 1.3784 - accuracy: 0.3187 - val_loss: 1.3752 - val_accuracy: 0.3333
# Epoch 33/100
# 16/16 [==============================] - 29s 2s/step - loss: 1.3838 - accuracy: 0.2725 - val_loss: 1.3744 - val_accuracy: 0.3333
# Epoch 34/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3740 - accuracy: 0.3280 - val_loss: 1.3715 - val_accuracy: 0.3333
# Epoch 35/100
# 16/16 [==============================] - 28s 2s/step - loss: 1.3762 - accuracy: 0.3023 - val_loss: 1.3702 - val_accuracy: 0.3333
# Epoch 36/100
# 16/16 [==============================] - 28s 2s/step - loss: 1.3831 - accuracy: 0.2993 - val_loss: 1.3711 - val_accuracy: 0.3333
# Epoch 37/100
# 16/16 [==============================] - 28s 2s/step - loss: 1.3786 - accuracy: 0.3104 - val_loss: 1.3733 - val_accuracy: 0.3333
# Epoch 38/100
# 16/16 [==============================] - 28s 2s/step - loss: 1.3845 - accuracy: 0.2807 - val_loss: 1.3750 - val_accuracy: 0.3333
# Epoch 39/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3893 - accuracy: 0.2450 - val_loss: 1.3765 - val_accuracy: 0.3333
# Epoch 40/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3845 - accuracy: 0.2682 - val_loss: 1.3781 - val_accuracy: 0.3333
# Epoch 41/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3818 - accuracy: 0.2695 - val_loss: 1.3790 - val_accuracy: 0.3333
# Epoch 42/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3842 - accuracy: 0.3147 - val_loss: 1.3759 - val_accuracy: 0.3333
# Epoch 43/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3888 - accuracy: 0.2568 - val_loss: 1.3746 - val_accuracy: 0.3333
# Epoch 44/100
# 16/16 [==============================] - 28s 2s/step - loss: 1.3856 - accuracy: 0.2758 - val_loss: 1.3758 - val_accuracy: 0.3333
# Epoch 45/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3828 - accuracy: 0.3085 - val_loss: 1.3748 - val_accuracy: 0.3333
# Epoch 46/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3852 - accuracy: 0.2848 - val_loss: 1.3740 - val_accuracy: 0.3333
# Epoch 47/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3703 - accuracy: 0.3513 - val_loss: 1.3721 - val_accuracy: 0.3333
# Epoch 48/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3888 - accuracy: 0.2601 - val_loss: 1.3727 - val_accuracy: 0.3333
# Epoch 49/100
# 16/16 [==============================] - 30s 2s/step - loss: 1.3795 - accuracy: 0.3235 - val_loss: 1.3720 - val_accuracy: 0.3333
# Epoch 50/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3856 - accuracy: 0.2719 - val_loss: 1.3724 - val_accuracy: 0.3333
# Epoch 51/100
# 16/16 [==============================] - 42s 3s/step - loss: 1.3773 - accuracy: 0.3118 - val_loss: 1.3723 - val_accuracy: 0.3333
# Epoch 52/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3923 - accuracy: 0.2668 - val_loss: 1.3735 - val_accuracy: 0.3333
# Epoch 53/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3826 - accuracy: 0.2954 - val_loss: 1.3743 - val_accuracy: 0.3333
# Epoch 54/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3858 - accuracy: 0.2836 - val_loss: 1.3748 - val_accuracy: 0.3333
# Epoch 55/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3878 - accuracy: 0.2590 - val_loss: 1.3751 - val_accuracy: 0.3333
# Epoch 56/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3775 - accuracy: 0.3274 - val_loss: 1.3735 - val_accuracy: 0.3333
# Epoch 57/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3832 - accuracy: 0.2829 - val_loss: 1.3730 - val_accuracy: 0.3333
# Epoch 58/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3930 - accuracy: 0.2419 - val_loss: 1.3754 - val_accuracy: 0.3333
# Epoch 59/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3827 - accuracy: 0.2918 - val_loss: 1.3771 - val_accuracy: 0.3333
# Epoch 60/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3853 - accuracy: 0.2776 - val_loss: 1.3789 - val_accuracy: 0.3333
# Epoch 61/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3788 - accuracy: 0.3105 - val_loss: 1.3779 - val_accuracy: 0.3333
# Epoch 62/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3820 - accuracy: 0.3008 - val_loss: 1.3770 - val_accuracy: 0.3333
# Epoch 63/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3884 - accuracy: 0.2604 - val_loss: 1.3765 - val_accuracy: 0.3333
# Epoch 64/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3769 - accuracy: 0.3262 - val_loss: 1.3751 - val_accuracy: 0.3333
# Epoch 65/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3803 - accuracy: 0.3066 - val_loss: 1.3749 - val_accuracy: 0.3333
# Epoch 66/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3748 - accuracy: 0.3188 - val_loss: 1.3747 - val_accuracy: 0.3333
# Epoch 67/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3861 - accuracy: 0.2760 - val_loss: 1.3751 - val_accuracy: 0.3333
# Epoch 68/100
# 16/16 [==============================] - 47s 3s/step - loss: 1.3826 - accuracy: 0.2968 - val_loss: 1.3742 - val_accuracy: 0.3333
# Epoch 69/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3772 - accuracy: 0.3202 - val_loss: 1.3730 - val_accuracy: 0.3333
# Epoch 70/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3726 - accuracy: 0.3345 - val_loss: 1.3722 - val_accuracy: 0.3333
# Epoch 71/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3722 - accuracy: 0.3399 - val_loss: 1.3704 - val_accuracy: 0.3333
# Epoch 72/100
# 16/16 [==============================] - 44s 3s/step - loss: 1.3716 - accuracy: 0.3297 - val_loss: 1.3700 - val_accuracy: 0.3333
# Epoch 73/100
# 16/16 [==============================] - 41s 3s/step - loss: 1.3949 - accuracy: 0.2572 - val_loss: 1.3720 - val_accuracy: 0.3333
# Epoch 74/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3874 - accuracy: 0.2605 - val_loss: 1.3734 - val_accuracy: 0.3333
# Epoch 75/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3773 - accuracy: 0.3165 - val_loss: 1.3732 - val_accuracy: 0.3333
# Epoch 76/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3771 - accuracy: 0.3100 - val_loss: 1.3731 - val_accuracy: 0.3333
# Epoch 77/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3776 - accuracy: 0.3084 - val_loss: 1.3738 - val_accuracy: 0.3333
# Epoch 78/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3803 - accuracy: 0.3021 - val_loss: 1.3741 - val_accuracy: 0.3333
# Epoch 79/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3871 - accuracy: 0.2712 - val_loss: 1.3741 - val_accuracy: 0.3333
# Epoch 80/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3896 - accuracy: 0.2505 - val_loss: 1.3753 - val_accuracy: 0.3333
# Epoch 81/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3860 - accuracy: 0.2746 - val_loss: 1.3764 - val_accuracy: 0.3333
# Epoch 82/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3871 - accuracy: 0.2649 - val_loss: 1.3772 - val_accuracy: 0.3333
# Epoch 83/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3746 - accuracy: 0.3463 - val_loss: 1.3752 - val_accuracy: 0.3333
# Epoch 84/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3870 - accuracy: 0.2683 - val_loss: 1.3764 - val_accuracy: 0.3333
# Epoch 85/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3847 - accuracy: 0.2753 - val_loss: 1.3770 - val_accuracy: 0.3333
# Epoch 86/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3912 - accuracy: 0.2377 - val_loss: 1.3785 - val_accuracy: 0.3333
# Epoch 87/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3814 - accuracy: 0.3128 - val_loss: 1.3779 - val_accuracy: 0.3333
# Epoch 88/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3875 - accuracy: 0.2476 - val_loss: 1.3769 - val_accuracy: 0.3333
# Epoch 89/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3832 - accuracy: 0.2811 - val_loss: 1.3768 - val_accuracy: 0.3333
# Epoch 90/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3820 - accuracy: 0.2899 - val_loss: 1.3769 - val_accuracy: 0.3333
# Epoch 91/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3812 - accuracy: 0.3023 - val_loss: 1.3765 - val_accuracy: 0.3333
# Epoch 92/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3858 - accuracy: 0.2644 - val_loss: 1.3771 - val_accuracy: 0.3333
# Epoch 93/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3774 - accuracy: 0.3088 - val_loss: 1.3774 - val_accuracy: 0.3333
# Epoch 94/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3865 - accuracy: 0.2928 - val_loss: 1.3771 - val_accuracy: 0.3333
# Epoch 95/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3807 - accuracy: 0.3197 - val_loss: 1.3752 - val_accuracy: 0.3333
# Epoch 96/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3855 - accuracy: 0.2725 - val_loss: 1.3738 - val_accuracy: 0.3333
# Epoch 97/100
# 16/16 [==============================] - 27s 2s/step - loss: 1.3854 - accuracy: 0.2747 - val_loss: 1.3741 - val_accuracy: 0.3333
# Epoch 98/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3915 - accuracy: 0.2553 - val_loss: 1.3743 - val_accuracy: 0.3333
# Epoch 99/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3717 - accuracy: 0.3439 - val_loss: 1.3734 - val_accuracy: 0.3333
# Epoch 100/100
# 16/16 [==============================] - 26s 2s/step - loss: 1.3762 - accuracy: 0.3278 - val_loss: 1.3725 - val_accuracy: 0.3333

# %%
#Understand the filters in the model 
#Let us pick the first hidden layer as the layer of interest.
layer = model.layers #Conv layers at 1, 3, 6, 8, 11, 13, 15
filters, biases = model.layers[1].get_weights()
print(layer[1].name, filters.shape)
# Out:
# conv2d (3, 3, 3, 64)

# %%
fig1=plt.figure(figsize=(12, 12))
columns = 8
rows = 8
n_filters = columns * rows
for i in range(1, n_filters +1):
    f = filters[:, :, :, i-1]
    fig1 =plt.subplot(rows, columns, i)
    fig1.set_xticks([])  #Turn off axis
    fig1.set_yticks([])
    plt.imshow(f[:, :, 0], cmap='jet') #Show only the filters from 0th channel (R)
    #ix += 1
plt.show()

# %%
### Now plot filter outputs    

#Define a new truncated model to only include the conv layers of interest
conv_layer_index = [1, 3, 6, 8, 11, 13, 15]
#conv_layer_index = [1, 3, 6]  #TO define a shorter model
outputs = [model.layers[i].output for i in conv_layer_index]
model_short = Model(inputs=model.inputs, outputs=outputs)
print(model_short.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_input (InputL [(None, 224, 224, 3)]     0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 226, 226, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 75, 75, 64)        1792
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 77, 77, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 25, 25, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 128)         147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 256)         295168
# _________________________________________________________________
# zero_padding2d_5 (ZeroPaddin (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 1, 256)         590080
# _________________________________________________________________
# zero_padding2d_6 (ZeroPaddin (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 1, 256)         590080
# =================================================================
# Total params: 1,735,488
# Trainable params: 1,735,488
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Input shape to the model is 224 x 224. SO resize input image to this shape.
from keras.preprocessing.image import load_img, img_to_array
img = load_img('/content/drive/MyDrive/Phd_Data_set_Implementation/Aug-Training-four/BL/HL_0_1013.jpeg', target_size=(224, 224)) #VGG user 224 as input

# convert the image to an array
img = img_to_array(img)
# expand dimensions to match the shape of model input
img = np.expand_dims(img, axis=0)

# Generate feature output by predicting on the input image
feature_output = model_short.predict(img)

# %%
#Input shape to the model is 224 x 224. SO resize input image to this shape.
from keras.preprocessing.image import load_img, img_to_array
img = load_img('/content/drive/MyDrive/Phd_Data_set_Implementation/Aug-Training-four/BL/HL_0_1013.jpeg', target_size=(224, 224)) #VGG user 224 as input

# convert the image to an array
img = img_to_array(img)
# expand dimensions to match the shape of model input
img = np.expand_dims(img, axis=0)

# Generate feature output by predicting on the input image
feature_output = model_short.predict(img)

# %%
columns = 8
rows = 8
for ftr in feature_output:
    #pos = 1
    fig=plt.figure(figsize=(12, 12))
    for i in range(1, columns*rows +1):
        fig =plt.subplot(rows, columns, i)
        fig.set_xticks([])  #Turn off axis
        fig.set_yticks([])
        plt.imshow(ftr[0, :, :, i-1], cmap='jet')
        #pos += 1
    plt.show()
